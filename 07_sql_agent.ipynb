# %%
from langchain.agents import create_sql_agent

agent = create_sql_agent(
    llm,
    db=db,
    agent_type="openai-tools",
    verbose=True
)

# %%
response = agent.run("Top 5 channels by total views")
print(response)
